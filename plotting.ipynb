# %% [markdown]
# Original Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the dataset
# file_path = "C:\\Users\\LOQ\\Desktop\\Uni Work\\FYP\\Depth Data\\MediaPipe Dataset\\right_arm_motion_eigth_realsense_(1).xlsx"
# file_path = r"C:\Users\LOQ\Desktop\Uni Work\FYP\Depth Data\Reference Templates\right_wrist_template_10_trails_demo.xlsx"
file_path = r"C:\Users\LOQ\Desktop\Uni Work\FYP\Depth Data\MediaPipe Dataset\Shahmir\right_arm_motion_eigth_realsense_(3).xlsx"

# file_path = "C:\\Users\\LOQ\\Desktop\\Uni Work\\FYP\\Depth Data\\Reference Templates\\right_wrist_template_10_trails_demo.xlsx"

df = pd.read_excel(file_path)

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot trajectories for Shoulder, Elbow, and Wrist
# We use different markers and labels for each joint to distinguish them
# ax.plot(df['Shoulder_x'], df['Shoulder_y'], df['Shoulder_z'], label='Shoulder', marker='o', markersize=3, alpha=0.7)
# ax.plot(df['Elbow_x'], df['Elbow_y'], df['Elbow_z'], label='Elbow', marker='^', markersize=3, alpha=0.7)
ax.plot(df['Wrist_x'], df['Wrist_y'], df['Wrist_z'], label='Wrist', marker='s', markersize=3, alpha=0.7)

# Set labels for the axes
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

# Add a title and legend
ax.set_title('3D Trajectory of Right Arm Motion')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# FLK data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the dataset
# file_path = 'right_arm_motion_eigth_realsense_FLK_GRU.xlsx'
# file_path = 'right_arm_motion_eigth_realsense_FLK_smooth.xlsx'
file_path = "C:\\Users\\LOQ\\Desktop\\Uni Work\\FYP\\Depth Data\\MediaPipe Dataset\\filtered\\right_arm_motion_eigth_realsense_(4)_FLK.xlsx"

df = pd.read_excel(file_path)

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot trajectories for Shoulder, Elbow, and Wrist
# We use different markers and labels for each joint to distinguish them
ax.plot(df['Shoulder_x'], df['Shoulder_y'], df['Shoulder_z'], label='Shoulder', marker='o', markersize=3, alpha=0.7)
ax.plot(df['Elbow_x'], df['Elbow_y'], df['Elbow_z'], label='Elbow', marker='^', markersize=3, alpha=0.7)
ax.plot(df['Wrist_x'], df['Wrist_y'], df['Wrist_z'], label='Wrist', marker='s', markersize=3, alpha=0.7)

# Set labels for the axes
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

# Add a title and legend
ax.set_title('3D Trajectory of Right Arm Motion')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# FLK GRU data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the dataset
# file_path = 'right_arm_motion_eigth_realsense_FLK_GRU.xlsx'
file_path = 'C:\\Users\\LOQ\\Desktop\\Uni Work\\FYP\\Depth Data\\MediaPipe Dataset\\filtered\\right_arm_motion_eigth_realsense_(4)_FLK_GRU.xlsx'
df = pd.read_excel(file_path)

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot trajectories for Shoulder, Elbow, and Wrist
# We use different markers and labels for each joint to distinguish them
ax.plot(df['Shoulder_x'], df['Shoulder_y'], df['Shoulder_z'], label='Shoulder', marker='o', markersize=3, alpha=0.7)
ax.plot(df['Elbow_x'], df['Elbow_y'], df['Elbow_z'], label='Elbow', marker='^', markersize=3, alpha=0.7)
ax.plot(df['Wrist_x'], df['Wrist_y'], df['Wrist_z'], label='Wrist', marker='s', markersize=3, alpha=0.7)

# Set labels for the axes
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

# Add a title and legend
ax.set_title('3D Trajectory of Right Arm Motion')
ax.legend()

# Show the plot
plt.show()
